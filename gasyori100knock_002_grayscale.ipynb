# %% [markdown]
# <a href="https://colab.research.google.com/github/mnabu55/Gasyori100knock/blob/master/gasyori100knock_002_grayscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Driveのファイルを読み込む方法については下記が参考になった
#
# https://qiita.com/uni-3/items/201aaa2708260cc790b8

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import numpy as np
import os
os.chdir('./gdrive/My Drive/Colab Notebooks/Gasyori100knock/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2
img = cv2.imread("imori.jpg")

# %%
def bgr2grayscale(out):
    b = img[:, :, 0].copy()
    g = img[:, :, 1].copy()
    r = img[:, :, 2].copy()

    # grayscale
    # Y = 0.2126 R + 0.7152 G + 0.0722 B
    out = 0.2126 * r + 0.7152 * g + 0.0722 * b
    out = out.astype(np.uint8)
    return out

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F6A332F66A0>

# %%
img = bgr2grayscale(img)

# ファイルに出力して保存する
cv2.imwrite("out.jpg", img)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=128x128 at 0x7F6A331822B0>

# %%
# !ls
# Out:
# 'Copy of gasyori100knock_003_.ipynb'   imori.jpg
#  Gasyori100knock_000.ipynb	       imori_noise.jpg
#  gasyori100knock_001.ipynb	       out.jpg
#  gasyori100knock_002_grayscale.ipynb
